# %% [markdown]
# #Act 2 - DataFrame SQL + Render & Spark Samples

# %%
#!pip install psycopg2-binary==2.9.12
#!pip install pyodbc
#!pip install python-oracledb
#!pip install cx_Oracle

# %%
#Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psycopg2

# %%
#Call db sample SQL in Render
conn = psycopg2.connect(
    dbname="transacoes_pbpt",
    user="transacoes_pbpt_user",
    password="TMigRMGDiJDMPz1efl0F4plHaNWjlHyF",
    host="dpg-cuqbmgggph6c73d0l5m0-a.ohio-postgres.render.com",
    port="5432"
)
#Call view SQL
query = """
    SELECT * FROM transacoes_clientes
    """
df = pd.read_sql(query, conn)
conn.close()
display(df)

# %%
#Replace this with the SQL sample models
sql_text = """
    SELECT * FROM media_customer_reviews_sample
"""

results = spark.sql(sql_text)
display(results)
