# %% [markdown]
# #Act 3 - DataFrame API Python Samples

# %%
#!pip install requests
#!pip install pandas

# %%
#Call libraries and create API generic function 
import requests
import json
import pandas as pd

def get_sample_data(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()

        data = response.json()
        return data

    except requests.RequestException as e:
        print(f"Erro na requisição: {e}")
        return None

    except (KeyError, ValueError) as e:
        print(f"Erro ao processar os dados: {e}")
        return None

# %%
#Call function to get sample data API (bitcoin)
data = get_sample_data("https://api.coinbase.com/v2/prices/BTC-USD/spot")
display(float(data["data"]["amount"]))
# Out:
# 61953.465

# %%
#Call function to get sample df API
data = get_sample_data("https://jsonplaceholder.typicode.com/posts")
df = pd.DataFrame(data)

display(df.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
